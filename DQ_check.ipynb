-- %%
-- Duplicate check
SELECT emp_id, COUNT(*)
FROM workspace.default.employee_silver
GROUP BY emp_id
HAVING COUNT(*) > 1;

-- Negative salary check
SELECT *
FROM workspace.default.employee_silver
WHERE ctc < 0;
