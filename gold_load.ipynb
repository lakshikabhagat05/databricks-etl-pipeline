-- %%
SELECT
    city,
    seniority_level,
    COUNT(*) AS total_employees,
    SUM(leave_flag) AS attrition_count,
    ROUND(100.0 * SUM(leave_flag)/COUNT(*), 2) AS attrition_rate
FROM workspace.default.employee_silver
GROUP BY city, seniority_level;
